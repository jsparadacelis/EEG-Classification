# %%
from eeg.eeg_exam import EEGexam

# %%
# Epileptic

# %%
path = "../exams/epileptic/00000355_s003_t000.edf"
eeg_epileptic_exam = EEGexam(path)
eeg_epileptic_exam.channels
# Out:
# ['EEG FP1-REF',
#  'EEG FP2-REF',
#  'EEG F3-REF',
#  'EEG F4-REF',
#  'EEG C3-REF',
#  'EEG C4-REF',
#  'EEG P3-REF',
#  'EEG P4-REF',
#  'EEG O1-REF',
#  'EEG O2-REF',
#  'EEG F7-REF',
#  'EEG F8-REF',
#  'EEG T3-REF',
#  'EEG T4-REF',
#  'EEG T5-REF',
#  'EEG T6-REF',
#  'EEG A1-REF',
#  'EEG A2-REF',
#  'EEG FZ-REF',
#  'EEG CZ-REF',
#  'EEG PZ-REF']

# %%
fp1_channel = eeg_epileptic_exam.channels[0]
eeg_epileptic_exam.plot_channel(fp1_channel)

# %%
eeg_epileptic_exam.plot_channel(fp1_channel, "freq")

# %%
# Non epileptic

# %%
path = "../exams/non-epileptic/00002744_s002_t002.edf"
eeg_non_epileptic_exam = EEGexam(path)

# %%
fp1_channel = eeg_non_epileptic_exam.channels[0]
eeg_non_epileptic_exam.plot_channel(fp1_channel)

# %%
eeg_non_epileptic_exam.plot_channel(fp1_channel, "freq")
